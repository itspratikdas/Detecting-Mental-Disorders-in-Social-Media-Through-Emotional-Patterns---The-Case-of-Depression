# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/MLproject/datasets/preprocessed_data.csv')

# %%
masked_data = pd.read_csv('/content/drive/MyDrive/MLproject/datasets/masked_dataset.csv')

# %%
data
# Out:
#                                                    text  is_depression
# 0     understand people reply immediately op invitat...              1
# 1     welcome r depression s check post place moment...              1
# 2     instead sleep depress stay night avoid day com...              1
# 3     ve kind stuff lot life delay inevitable have w...              1
# 4     sleep great comforting escape wake day literal...              1
# ...                                                 ...            ...
# 7726                                               snow              0
# 7727                               moulin rouge mad cry              0
# 7728                       try shout t find people list              0
# 7729  ughh t find red sox hat get to wear creepy nic...              0
# 7730  sleep wonderfully finally try swatching new pr...              0
#
# [7731 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7731 entries, 0 to 7730
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   text           7727 non-null   object
#  1   is_depression  7731 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 120.9+ KB

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7727 entries, 0 to 7730
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   text           7727 non-null   object
#  1   is_depression  7727 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 181.1+ KB

# %% [markdown]
# here we are executing for simple dataset without subemtion...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.text,data.is_depression , test_size = 0.30)

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer(ngram_range=(1,2))
X_train_cv = v.fit_transform(X_train.values)
X_test_cv = v.transform(X_test.values)
type(X_train_cv)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Train the SVM classifier
svm_classifier.fit(X_train_cv, y_train)

# Make predictions on the test set
y_pred = svm_classifier.predict(X_test_cv)

# %%
# Calculate accuracy
print(classification_report(y_test,y_pred))

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      1176
#            1       0.98      0.92      0.95      1143
#
#     accuracy                           0.95      2319
#    macro avg       0.95      0.95      0.95      2319
# weighted avg       0.95      0.95      0.95      2319
#
# Accuracy: 0.9508408796895214

# %% [markdown]
# Now do evaluation for masked data (masked with subemotion)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(masked_data.masked_text,masked_data.is_depression , test_size = 0.30)

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer(ngram_range=(1,2))
X_train_cv = v.fit_transform(X_train.values)
X_test_cv = v.transform(X_test.values)
type(X_train_cv)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Train the SVM classifier
svm_classifier.fit(X_train_cv, y_train)

# Make predictions on the test set
y_pred = svm_classifier.predict(X_test_cv)

# %%
# Calculate accuracy
print(classification_report(y_test,y_pred))

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       135
#            1       1.00      1.00      1.00       165
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# Accuracy: 1.0
